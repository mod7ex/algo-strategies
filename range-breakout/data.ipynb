# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

df.set_index("timestamp ET", inplace=True)

df.index.name = "Datetime"

df = df[["Open", "High", "Low", "Close"]]

df
# Out:
#                       Open      High       Low     Close
# Datetime
# 12/26/2022 18:01  13759.00  13794.75  13759.00  13788.50
# 12/26/2022 18:02  13790.25  13794.00  13784.00  13790.25
# 12/26/2022 18:03  13789.75  13791.75  13782.50  13784.25
# 12/26/2022 18:04  13783.00  13783.25  13776.00  13777.25
# 12/26/2022 18:05  13777.75  13783.50  13777.50  13783.50
# ...                    ...       ...       ...       ...
# 12/11/2025 20:48  25922.75  25926.50  25921.50  25924.75
# 12/11/2025 20:49  25924.00  25925.25  25920.75  25923.75
# 12/11/2025 20:50  25924.00  25924.25  25920.75  25922.75
# 12/11/2025 20:51  25923.25  25923.50  25921.50  25923.50
# 12/11/2025 20:52  25925.25  25926.00  25917.50  25919.50
#
# [1048575 rows x 4 columns]
