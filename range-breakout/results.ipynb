# %%
import pandas as pd
import numpy as np

# %%
CSV_FILE = "XAUUSD-5M-RB-performance-test.csv"

results_df = pd.read_csv(CSV_FILE).dropna()
results_df = results_df[
    (results_df["ct"] < "17:00") &
    (results_df["ct"] > "10:00") &
    (results_df["rr"] != 1)
]
results_df.set_index(["ct", "rl", "rr", "mlh"], inplace=True)
# results_df.sort_values("Max loss streak", inplace=True, ascending=True)
results_df.sort_values("Sharp ratio", inplace=True, ascending=False)
# results_df.to_html(CSV_FILE.replace("csv", "html"))
results_df.head(20)
# Out:
#                  Return %  Sharp ratio  Max Balance DD  Max Balance DD %  \
# ct    rl rr mlh
# 13:20 1  3  21     107.96      1499.84          146.53              9.18
#             12     101.32      1465.71          141.40              9.26
#             20     103.88      1448.98          138.09              8.82
#             19     102.02      1422.42          130.69              8.81
#             22     102.64      1393.44          148.10              9.54
#             30     104.83      1391.79          149.63              9.48
#             29     105.08      1390.89          130.25              8.91
#             13      98.14      1388.83          147.01              9.70
#             27     104.06      1383.43          141.56              9.01
#             14      97.97      1380.54          144.21              9.53
#             31     104.04      1379.19          140.92              8.97
#             28     103.66      1370.71          143.53              9.18
#             18      97.63      1363.84          149.84              9.68
# 14:35 1  2  17      94.14      1360.61          115.32              7.89
#             16      93.23      1359.47          118.15              7.21
#          3  16     108.84      1356.38          188.34             13.67
# 13:20 1  3  26     101.65      1354.42          145.07              9.32
#          2  19      82.85      1347.24          154.78             10.07
#             26      83.96      1342.42          152.26             10.00
# 14:35 1  2  23      93.45      1336.27          130.00              8.07
#
#                  Win rate  Winning trades  Losing trades  N° trades  \
# ct    rl rr mlh
# 13:20 1  3  21      36.16             132            233        365
#             12      39.18             143            222        365
#             20      35.89             131            234        365
#             19      36.16             132            233        365
#             22      35.62             130            235        365
#             30      33.42             122            243        365
#             29      33.42             122            243        365
#             13      37.91             138            226        364
#             27      33.70             123            242        365
#             14      38.08             139            226        365
#             31      33.42             122            243        365
#             28      33.42             122            243        365
#             18      35.89             131            234        365
# 14:35 1  2  17      42.74             156            209        365
#             16      43.01             157            208        365
#          3  16      35.89             131            234        365
# 13:20 1  3  26      33.42             122            243        365
#          2  19      41.92             153            212        365
#             26      41.37             151            214        365
# 14:35 1  2  23      42.47             155            210        365
#
#                  Max win streak  Max loss streak
# ct    rl rr mlh
# 13:20 1  3  21                6               11
#             12                6               11
#             20                6               11
#             19                6               11
#             22                6               11
#             30                6               11
#             29                6               11
#             13                6               11
#             27                6               11
#             14                6               11
#             31                6               11
#             28                6               11
#             18                6               11
# 14:35 1  2  17                6                8
#             16                6                8
#          3  16                4               11
# 13:20 1  3  26                6               11
#          2  19                8                9
#             26                6                9
# 14:35 1  2  23                6               10
