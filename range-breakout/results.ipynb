# %%
import pandas as pd
import numpy as np

# %%
CSV_FILE = "performance-test.csv"

performance_test_results_df = pd.read_csv(CSV_FILE).dropna()
performance_test_results_df = performance_test_results_df[performance_test_results_df["rr"] != 1]
performance_test_results_df.set_index(["rl", "rr", "ct"], inplace=True)
performance_test_results_df.sort_values("Sharp ratio", inplace=True, ascending=False)
# performance_test_results_df.to_html(CSV_FILE.replace("csv", "html"))
performance_test_results_df.head(20)
# Out:
#              mlh  Return %  Sharp ratio  Max Balance DD  Max Balance DD %  \
# rl rr ct
# 12 2  05:35   50     10.55       170.84           20.16              1.99
# 5  2  05:35   20      9.50       159.12           34.06              3.35
#       05:35   50     10.56       136.97           43.64              4.25
# 12 2  05:35   20      3.99       121.91           20.00              1.96
#       05:40   50      5.37        91.63           22.20              2.19
#       05:40   20      2.69        89.71           15.08              1.45
# 5  2  05:40   20      2.64        55.86           39.93              3.75
# 12 2  05:45   50      2.52        44.95           39.91              3.94
# 5  2  05:40   50      3.25        43.65           41.95              4.07
#       05:55   50      1.36        18.31           70.00              6.50
# 12 2  05:50   50      0.98        17.93           50.13              4.93
# 5  2  05:45   50      0.17         2.44           55.28              5.40
#
#              Win rate  Winning trades  Losing trades  N° trades  \
# rl rr ct
# 12 2  05:35     55.56              20             16         36
# 5  2  05:35     61.11              22             14         36
#       05:35     50.00              18             18         36
# 12 2  05:35     54.29              19             16         35
#       05:40     50.00              18             18         36
#       05:40     58.82              20             14         34
# 5  2  05:40     61.11              22             14         36
# 12 2  05:45     42.86              15             20         35
# 5  2  05:40     41.67              15             21         36
#       05:55     37.84              14             23         37
# 12 2  05:50     42.86              15             20         35
# 5  2  05:45     36.11              13             23         36
#
#              Max win streak  Max loss streak
# rl rr ct
# 12 2  05:35               5                3
# 5  2  05:35               4                3
#       05:35               3                3
# 12 2  05:35               5                4
#       05:40               3                3
#       05:40               4                3
# 5  2  05:40               4                3
# 12 2  05:45               3                6
# 5  2  05:40               3                3
#       05:55               3                7
# 12 2  05:50               3                6
# 5  2  05:45               3                6
