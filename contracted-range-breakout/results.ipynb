# %%
import pandas as pd
import numpy as np

# %% [markdown]
# > MT5 Server Time = UTC+3

# %%
CSV_FILE = "performance-test.csv"

results_df = pd.read_csv(CSV_FILE).dropna()
results_df.set_index(["mrd", "rl", "rr", "mlh"], inplace=True)
# results_df.sort_values("Max loss streak", inplace=True, ascending=True)
results_df.sort_values("Sharp ratio", inplace=True, ascending=False)
# results_df.to_html(CSV_FILE.replace("csv", "html"))
results_df.head(20)
# Out:
#                Return %  Sharp ratio  Max Balance DD  Max Balance DD %  \
# mrd rl rr mlh
# 4   5  2  20      96.58       789.42          413.04             22.97
#     12 2  20      44.92       773.28           90.25              7.53
#     5  2  50      57.92       450.31          445.14             25.38
# 2   5  2  50      32.02       449.87          140.00             10.77
# 4   12 2  50      26.43       403.63          247.50             19.99
# 2   5  2  20      18.73       260.51          231.88             17.54
#     12 2  50       1.00        55.06           70.00              6.48
#           20       0.21        13.10           74.23              6.90
#
#                Win rate %  Winning trades  Losing trades  N° trades  \
# mrd rl rr mlh
# 4   5  2  20        40.31             776           1149       1925
#     12 2  20        48.13             180            194        374
#     5  2  50        35.03             579           1074       1653
# 2   5  2  50        36.44             129            225        354
# 4   12 2  50        38.95             111            174        285
# 2   5  2  20        36.89             135            231        366
#     12 2  50        35.29               6             11         17
#           20        47.37               9             10         19
#
#                Max win streak  Max loss streak
# mrd rl rr mlh
# 4   5  2  20                8               17
#     12 2  20                5                7
#     5  2  50                8               16
# 2   5  2  50                4                8
# 4   12 2  50                4               10
# 2   5  2  20                4                8
#     12 2  50                5                6
#           20                5                6
