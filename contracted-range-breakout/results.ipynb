# %%
import pandas as pd
import numpy as np

# %% [markdown]
# > MT5 Server Time = UTC+3

# %%
CSV_FILE = "performance-test.csv"

results_df = pd.read_csv(CSV_FILE).dropna()
results_df.set_index(["mrd", "rl", "rr", "mlh"], inplace=True)
results_df.sort_values("Sharp ratio", inplace=True, ascending=False)
# results_df.sort_values("Max loss streak", inplace=True, ascending=True)
# results_df.to_html(CSV_FILE.replace("csv", "html"))
results_df.head(20)
# Out:
#                 Return %  Sharp ratio  Max Balance DD  Max Balance DD %  \
# mrd rl rr  mlh
# 2.5 2  3.0 19     389.66      3183.84          332.98             12.80
# 3.0 2  3.0 20     392.60      3087.50          494.09             11.33
# 2.5 2  3.0 20     368.53      2889.71          377.09             19.52
#        3.5 13     389.01      2810.33          390.18             13.60
#        3.0 18     368.43      2798.85          329.19             17.12
#        3.5 12     398.25      2757.85          364.86             27.02
# 3.0 2  3.5 15     415.59      2682.99          506.37             17.62
# 2.5 2  3.0 14     349.78      2663.96          367.41             17.58
# 3.0 2  3.0 22     366.43      2663.90          528.02             12.64
#        3.5 20     394.65      2656.04          560.63             17.81
#        3.0 19     365.17      2654.51          488.82             12.38
# 2.5 2  3.0 12     358.47      2651.86          379.52             22.61
#        3.5 14     372.69      2607.21          379.32             17.68
# 3.0 2  4.0 15     417.91      2603.34          494.40             23.24
#            20     406.69      2576.76          475.24             23.47
# 2.5 2  2.0 19     337.60      2540.48          320.68             30.04
#        3.5 19     376.09      2512.77          372.71             17.44
#        3.0 29     339.96      2494.04          337.71             20.23
# 3.0 2  3.0 23     349.24      2479.56          502.73             13.77
# 2.5 2  3.5 20     384.31      2456.70          369.45             27.89
#
#                 Win rate %  Winning trades  Losing trades  N° trades  \
# mrd rl rr  mlh
# 2.5 2  3.0 19        31.61            1000           2164       3164
# 3.0 2  3.0 20        30.77            1284           2889       4173
# 2.5 2  3.0 20        31.07             975           2163       3138
#        3.5 13        32.63            1110           2292       3402
#        3.0 18        31.67            1010           2179       3189
#        3.5 12        33.65            1173           2313       3486
# 3.0 2  3.5 15        31.69            1382           2979       4361
# 2.5 2  3.0 14        32.88            1112           2270       3382
# 3.0 2  3.0 22        30.18            1241           2871       4112
#        3.5 20        29.05            1181           2885       4066
#        3.0 19        31.09            1312           2908       4220
# 2.5 2  3.0 12        34.50            1217           2311       3528
#        3.5 14        31.67            1058           2283       3341
# 3.0 2  4.0 15        30.73            1326           2989       4315
#            20        28.18            1122           2859       3981
# 2.5 2  2.0 19        37.74            1312           2164       3476
#        3.5 19        29.52             917           2189       3106
#        3.0 29        29.09             865           2109       2974
# 3.0 2  3.0 23        29.90            1216           2851       4067
# 2.5 2  3.5 20        29.29             903           2180       3083
#
#                 Max win streak  Max loss streak
# mrd rl rr  mlh
# 2.5 2  3.0 19                7               17
# 3.0 2  3.0 20                6               14
# 2.5 2  3.0 20                6               16
#        3.5 13                6               19
#        3.0 18                6               16
#        3.5 12                6               16
# 3.0 2  3.5 15                8               15
# 2.5 2  3.0 14                8               21
# 3.0 2  3.0 22                7               14
#        3.5 20                5               21
#        3.0 19                6               14
# 2.5 2  3.0 12                6               16
#        3.5 14                8               21
# 3.0 2  4.0 15                7               15
#            20                6               21
# 2.5 2  2.0 19                7               17
#        3.5 19                6               17
#        3.0 29                6               21
# 3.0 2  3.0 23                6               21
# 2.5 2  3.5 20                6               16
