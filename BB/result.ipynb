# %%
import pandas as pd

# %%
CSV_FILE = "test-result.csv"

df = pd.read_csv(CSV_FILE).dropna()
df.set_index(["bbw", "bbz", "aw", "rr", "am", "mlh"], inplace=True)
df.sort_values("Sharp ratio", inplace=True, ascending=False)
# df.to_html(CSV_FILE.replace("csv", "html"))
df.head(20)
# Out:
#                         Return %  Sharp ratio  Max Balance DD  \
# bbw bbz aw rr  am  mlh
# 10  2.0 9  0.5 2.0 3      2251.5     74239.21            40.0
#         8  0.5 2.0 3      2244.0     72416.98            40.0
#         10 0.5 2.0 3      2226.5     71919.64            40.0
#         11 0.5 2.0 3      2200.5     71883.66            40.0
#         12 0.5 2.0 3      2205.0     71757.96            45.0
#         6  0.5 2.0 3      2242.5     71261.39            35.0
#         13 0.5 2.0 3      2199.0     71233.64            50.0
#         7  0.5 2.0 3      2229.0     70862.10            35.0
#         14 0.5 2.0 3      2174.0     70722.75            50.0
#         5  0.5 2.0 3      2249.0     70328.99            40.0
#         7  0.5 1.5 3      2406.0     68114.48            50.0
#         14 0.5 1.5 3      2387.0     67927.07            45.0
#         12 0.5 1.5 3      2390.0     67803.36            55.0
#         3  0.5 2.0 3      2166.0     67710.98            50.0
# ...
